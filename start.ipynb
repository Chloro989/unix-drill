# %% [markdown]
# # UNIX コマンド練習ドリル v2
#
# Google Colab 用のノートブックです。上から順にセルを実行してください。
#
# **このノートブックと同じ場所に `unix_drill` フォルダを置いてください。**
# zip をアップロードした場合は、次のセルで展開できます。

# %%
# zip をアップロードした場合だけ実行（すでにフォルダがあるなら飛ばす）
# from google.colab import files; files.upload()
# !ls -d unix_drill 2>/dev/null || unzip -q unix_drill.zip

# %% [markdown]
# ## 1. 準備
#
# データを作ります。数秒で終わります。

# %%
# %cd /content/unix_drill
# !bash setup.sh

# %% [markdown]
# ## 2. 章の解説を読む
#
# 第1〜9章まであります。番号を変えて実行してください。
#
# 1 場所とファイル / 2 中を覗く / 3 リダイレクト / 4 パイプ / 5 grep /
# 6 正規表現 / 7 sort・uniq・cut / 8 awk / 9 sed

# %%
# !python3 drill.py lesson 1

# %% [markdown]
# ## 3. 問題を解く
#
# セルを実行すると問題が出ます。**下に現れる入力欄にコマンドを打って Enter。**
#
# - `hint` … 段階的なヒント
# - `files` … ファイル一覧
# - `skip` … とばす
# - `quit` … 終了（進捗は保存されます）

# %%
# !python3 drill.py play 1

# %% [markdown]
# ## 4. 続きから / 復習 / 進捗

# %%
# !python3 drill.py          # 続きから

# %%
# !python3 drill.py review   # 間違えた問題だけ

# %%
# !python3 drill.py progress

# %% [markdown]
# ## 5. 本物のシェルでも試す（フィールドモード）
#
# `playground/` の中は好きなだけ壊してかまいません。
# `!bash setup.sh` でいつでも作り直せます。

# %%
# !cd playground && ls -l && head -n 4 *.fastq 2>/dev/null | head -8

# %%
# !python3 drill.py show  1-03
# !python3 drill.py check 1-03 'ls -a notes'

# %% [markdown]
# ## 6. 題材を変える
#
# 同じ問題を別のデータで解き直せます（`bio` / `logs` / `general`）。

# %%
# !python3 drill.py theme
